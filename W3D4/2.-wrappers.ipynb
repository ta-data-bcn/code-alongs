# %%
import forecastio

# %%
Key = "0bfa820c54f7c641b1ca1efde7ed506e"

# %%
lat = 41
lon = 2

# %%
forecast = forecastio.load_forecast(key=Key, lat=lat, lng=lon)

# %%
forecast.json
# Out:
# {'latitude': 41,
#  'longitude': 2,
#  'timezone': 'Europe/Madrid',
#  'currently': {'time': 1562841849,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 24.09,
#   'apparentTemperature': 25.05,
#   'dewPoint': 23.33,
#   'humidity': 0.96,
#   'pressure': 1014.36,
#   'windSpeed': 9.49,
#   'windGust': 9.49,
#   'windBearing': 223,
#   'cloudCover': 0.17,
#   'uvIndex': 8,
#   'visibility': 11.084,
#   'ozone': 316.3},
#  'hourly': {'summary': 'Humid and partly cloudy throughout the day.',
#   'icon': 'clear-day',
#   'data': [{'time': 1562839200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 23.85,
#     'apparentTemperature': 24.84,
#     'dewPoint': 23.44,
#     'humidity': 0.98,
#     'pressure': 1014.64,
#     'windSpeed': 9.13,
#     'windGust': 9.13,
# ...

# %%
from stackapi import StackAPI

# %%
SITE = StackAPI('stackoverflow')

# %%
comments = SITE.fetch('comments')

# %%
comments
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 1331,
#     'user_id': 2353185,
#     'user_type': 'registered',
#     'accept_rate': 42,
#     'profile_image': 'https://www.gravatar.com/avatar/42570361989e3fba1f7ec3f8110901aa?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'henry',
#     'link': 'https://stackoverflow.com/users/2353185/henry'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1562842352,
#    'post_id': 56987478,
#    'comment_id': 100509575},
#   {'owner': {'reputation': 70821,
#     'user_id': 1591669,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://i.stack.imgur.com/oh6VZ.png?s=128&g=1',
#     'display_name': 'unor',
#     'link': 'https://stackoverflow.com/users/1591669/unor'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1562842351,
#    'post_id': 56981349,
# ...

# %% [markdown]
# * Question 1: You want the questions and the answers of the last month
# * Question 2: Most voted question today with at least a score of 5 and tagged with 'python'
# * Question 3: You want the answers with id 6784 and 6473

# %%
questions = SITE.fetch('questions', fromdate=1562842659, todate=1572994800)

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['php', 'laravel'],
#    'owner': {'reputation': 1,
#     'user_id': 6427661,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/1110193905705728/picture?type=large',
#     'display_name': 'Ramy Merheb',
#     'link': 'https://stackoverflow.com/users/6427661/ramy-merheb'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': -1,
#    'last_activity_date': 1562842954,
#    'creation_date': 1562842916,
#    'last_edit_date': 1562842954,
#    'question_id': 56987743,
#    'link': 'https://stackoverflow.com/questions/56987743/laratrust-wherepermissionis-returning-illuminate-database-queryexception-error',
#    'title': 'laratrust wherePermissionIs returning Illuminate/Database/QueryException error'},
#   {'tags': ['c++', 'qt'],
#    'owner': {'reputation': 1,
#     'user_id': 10551526,
# ...

# %%
question2 = SITE.fetch('questions', fromdate=1562796000, todate=1562843112,
    tagged='python', sort='votes', min=5)

# %%
question2
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'pandas', 'dataframe'],
#    'owner': {'reputation': 70,
#     'user_id': 8561125,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/1EBVj.jpg?s=128&g=1',
#     'display_name': 'Ching',
#     'link': 'https://stackoverflow.com/users/8561125/ching'},
#    'is_answered': True,
#    'view_count': 61,
#    'accepted_answer_id': 56982159,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1562823432,
#    'creation_date': 1562822209,
#    'last_edit_date': 1562822348,
#    'question_id': 56982048,
#    'link': 'https://stackoverflow.com/questions/56982048/find-element-in-list-in-datafame',
#    'title': 'find element in list in datafame'}]}
