# %%
import pandas as pd

# %%
df = pd.read_csv("vehicles.csv")

# %%
df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
 pd.read_csv("vehicles_tab.txt").head()
# Out:
#   Make\tModel\tYear\tEngine Displacement\tCylinders\tTransmission\tDrivetrain\tVehicle Class\tFuel Type\tFuel Barrels/Year\tCity MPG\tHighway MPG\tCombined MPG\tCO2 Emission Grams/Mile\tFuel Cost/Year
# 0  AM General\tDJ Po Vehicle 2WD\t1984\t2.5\t4.0\...
# 1  AM General\tFJ8c Post Office\t1984\t4.2\t6.0\t...
# 2  AM General\tPost Office DJ5 2WD\t1985\t2.5\t4....
# 3  AM General\tPost Office DJ8 2WD\t1985\t4.2\t6....
# 4  ASC Incorporated\tGNX\t1987\t3.8\t6.0\tAutomat...

# %%
 pd.read_csv("vehicles_tab.txt", sep="\t")
# Out:
#                 Make                Model  Year  Engine Displacement  \
# 0         AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1         AM General     FJ8c Post Office  1984                  4.2
# 2         AM General  Post Office DJ5 2WD  1985                  2.5
# 3         AM General  Post Office DJ8 2WD  1985                  4.2
# 4   ASC Incorporated                  GNX  1987                  3.8
# 5              Acura          2.2CL/3.0CL  1997                  2.2
# 6              Acura          2.2CL/3.0CL  1997                  2.2
# 7              Acura          2.2CL/3.0CL  1997                  3.0
# 8              Acura          2.3CL/3.0CL  1998                  2.3
# 9              Acura          2.3CL/3.0CL  1998                  2.3
# 10             Acura          2.3CL/3.0CL  1998                  3.0
# 11             Acura          2.3CL/3.0CL  1999                  2.3
# 12             Acura          2.3CL/3.0CL  1999                  2.3
# ...

# %%
 pd.read_csv("vehicles_tab.txt", sep="    ")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    Make\tModel\tYear\tEngine Displacement\tCylinders\tTransmission\tDrivetrain\tVehicle Class\tFuel Type\tFuel Barrels/Year\tCity MPG\tHighway MPG\tCombined MPG\tCO2 Emission Grams/Mile\tFuel Cost/Year
# 0   AM General\tDJ Po Vehicle 2WD\t1984\t2.5\t4.0\...
# 1   AM General\tFJ8c Post Office\t1984\t4.2\t6.0\t...
# 2   AM General\tPost Office DJ5 2WD\t1985\t2.5\t4....
# 3   AM General\tPost Office DJ8 2WD\t1985\t4.2\t6....
# 4   ASC Incorporated\tGNX\t1987\t3.8\t6.0\tAutomat...
# 5   Acura\t2.2CL/3.0CL\t1997\t2.2\t4.0\tAutomatic ...
# 6   Acura\t2.2CL/3.0CL\t1997\t2.2\t4.0\tManual 5-s...
# ...

# %%
pd.read_json("vehicles.json").head()
# Out:
#    CO2 Emission Grams/Mile  City MPG  Combined MPG  Cylinders  \
# 0               522.764706        18            17          4
# 1               683.615385        13            13          6
# 2               555.437500        16            16          4
# 3               683.615385        13            13          6
# 4               555.437500        14            16          6
#
#          Drivetrain  Engine Displacement  Fuel Barrels/Year  Fuel Cost/Year  \
# 0     2-Wheel Drive                  2.5          19.388824            1950
# 1     2-Wheel Drive                  4.2          25.354615            2550
# 2  Rear-Wheel Drive                  2.5          20.600625            2100
# 3  Rear-Wheel Drive                  4.2          25.354615            2550
# 4  Rear-Wheel Drive                  3.8          20.600625            2550
#
#   Fuel Type  Highway MPG              Make                Model  \
# 0   Regular           17        AM General    DJ Po Vehicle 2WD
# ...

# %%
df = pd.read_csv("vehicles.csv")

# %%
df
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
df.sort_values(by="Year")
# Out:
#                 Make                           Model  Year  \
# 0         AM General               DJ Po Vehicle 2WD  1984
# 16337            GMC            T15 (S15) Pickup 4WD  1984
# 16336            GMC            T15 (S15) Pickup 4WD  1984
# 5636       Chevrolet            El Camino Pickup 2WD  1984
# 5637       Chevrolet            El Camino Pickup 2WD  1984
# 5638       Chevrolet            El Camino Pickup 2WD  1984
# 5639       Chevrolet            El Camino Pickup 2WD  1984
# 5640       Chevrolet            El Camino Pickup 2WD  1984
# 5641       Chevrolet            El Camino Pickup 2WD  1984
# 5642       Chevrolet            El Camino Pickup 2WD  1984
# 16335            GMC            T15 (S15) Pickup 4WD  1984
# 7485       Chevrolet            T10 (S10) Pickup 4WD  1984
# 16334            GMC            T15 (S15) Pickup 4WD  1984
# 16332            GMC            T15 (S15) Pickup 4WD  1984
# 10671          Dodge              Rampage Pickup 2WD  1984
# ...

# %%
df[df["Year"] == 1984]
# Out:
#                                    Make                    Model  Year  \
# 0                            AM General        DJ Po Vehicle 2WD  1984
# 1                            AM General         FJ8c Post Office  1984
# 353         American Motors Corporation                Eagle 4WD  1984
# 354         American Motors Corporation                Eagle 4WD  1984
# 355         American Motors Corporation                Eagle 4WD  1984
# 356         American Motors Corporation                Eagle 4WD  1984
# 357         American Motors Corporation                Eagle 4WD  1984
# 358         American Motors Corporation                Eagle 4WD  1984
# 359         American Motors Corporation                Eagle 4WD  1984
# 362         American Motors Corporation           Eagle SX/4 4WD  1984
# 363         American Motors Corporation           Eagle SX/4 4WD  1984
# 364         American Motors Corporation           Eagle SX/4 4WD  1984
# ...

# %%
df[df["Year"] == 1984].to_csv("I_am_year_1984.csv")

# %%
years = list(set(df["Year"]))

# %%
for year in years:
    df[df["Year"] == year].to_csv(f"I_am_year_{year}.csv")

# %%
safe_number_of_rows = 1200

# %%
for year in years:
    if df[df["Year"] == year].shape[0] < safe_number_of_rows:
        df[df["Year"] == year].to_csv(f"I_am_year_{year}.csv")
    else:
        print(f"No way Jose for year {year}")
# Out:
# No way Jose for year 1985
# No way Jose for year 2014
# No way Jose for year 2015
# No way Jose for year 2016

# %%
df.shape[0]
# Out:
# 35952

# %%
for year in years:
    df_year = df[df["Year"] == year]
    if df_year.shape[0] < safe_number_of_rows:
        df_year.to_csv(f"I_am_year_{year}.csv")
    else:
        print(f"No way Jose for year {year}")
# Out:
# No way Jose for year 1985
# No way Jose for year 2014
# No way Jose for year 2015
# No way Jose for year 2016

# %% [markdown]
# ## Database

# %%
from sqlalchemy import create_engine

# %%
driver = 'mysql+pymysql:'
user = 'ironhacker_read'
password = 'ir0nhack3r'
ip = '35.239.232.23'
database = 'publications'

# %%
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'

# %%
engine = create_engine(connection_string)

# %%
query = """
        SELECT * FROM authors
"""

# %%
df_db = pd.read_sql(query, engine)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df_db

# %%
query = """
        CREATE TABLE kerim_table
        SELECT * FROM authors
"""
df_db = pd.read_sql(query, engine)

# %%
print(query)
