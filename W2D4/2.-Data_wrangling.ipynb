# %%
# Importing libraries
import pandas as pd

# %%
ufo_table = pd.read_csv("scrubbed.csv", low_memory=False)

# %%
ufo_table
# Out:
#                datetime                                   city state country  \
# 0      10/10/1949 20:30                             san marcos    tx      us
# 1      10/10/1949 21:00                           lackland afb    tx     NaN
# 2      10/10/1955 17:00                   chester (uk/england)   NaN      gb
# 3      10/10/1956 21:00                                   edna    tx      us
# 4      10/10/1960 20:00                                kaneohe    hi      us
# 5      10/10/1961 19:00                                bristol    tn      us
# 6      10/10/1965 21:00                     penarth (uk/wales)   NaN      gb
# 7      10/10/1965 23:45                                norwalk    ct      us
# 8      10/10/1966 20:00                              pell city    al      us
# 9      10/10/1966 21:00                               live oak    fl      us
# 10     10/10/1968 13:00                              hawthorne    ca      us
# ...

# %%
ufo_table.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %%
ufo_table.rename(columns={"duration (hours/min)": "duration_hours_min", "date posted":"date_posted", "duration (seconds)":"duration_seconds", "longitude ":"longitude"})
# Out:
#                datetime                                   city state country  \
# 0      10/10/1949 20:30                             san marcos    tx      us
# 1      10/10/1949 21:00                           lackland afb    tx     NaN
# 2      10/10/1955 17:00                   chester (uk/england)   NaN      gb
# 3      10/10/1956 21:00                                   edna    tx      us
# 4      10/10/1960 20:00                                kaneohe    hi      us
# 5      10/10/1961 19:00                                bristol    tn      us
# 6      10/10/1965 21:00                     penarth (uk/wales)   NaN      gb
# 7      10/10/1965 23:45                                norwalk    ct      us
# 8      10/10/1966 20:00                              pell city    al      us
# 9      10/10/1966 21:00                               live oak    fl      us
# 10     10/10/1968 13:00                              hawthorne    ca      us
# ...

# %%
ufo_table
# Out:
#                datetime                                   city state country  \
# 0      10/10/1949 20:30                             san marcos    tx      us
# 1      10/10/1949 21:00                           lackland afb    tx     NaN
# 2      10/10/1955 17:00                   chester (uk/england)   NaN      gb
# 3      10/10/1956 21:00                                   edna    tx      us
# 4      10/10/1960 20:00                                kaneohe    hi      us
# 5      10/10/1961 19:00                                bristol    tn      us
# 6      10/10/1965 21:00                     penarth (uk/wales)   NaN      gb
# 7      10/10/1965 23:45                                norwalk    ct      us
# 8      10/10/1966 20:00                              pell city    al      us
# 9      10/10/1966 21:00                               live oak    fl      us
# 10     10/10/1968 13:00                              hawthorne    ca      us
# ...

# %%
ufo_table = ufo_table.rename(columns={"duration (hours/min)": "duration_hours_min", "date posted":"date_posted", "duration (seconds)":"duration_seconds", "longitude ":"longitude"})

# %%
ufo_table.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration_seconds duration_hours_min  \
# 0             2700         45 minutes
# 1             7200            1-2 hrs
# 2               20         20 seconds
# 3               20           1/2 hour
# 4              900         15 minutes
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# ...

# %%
ufo_table.dtypes
# Out:
# datetime               object
# city                   object
# state                  object
# country                object
# shape                  object
# duration_seconds       object
# duration_hours_min     object
# comments               object
# date_posted            object
# latitude               object
# longitude             float64
# dtype: object

# %%
ufo_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime              80332 non-null object
# city                  80332 non-null object
# state                 74535 non-null object
# country               70662 non-null object
# shape                 78400 non-null object
# duration_seconds      80332 non-null object
# duration_hours_min    80332 non-null object
# comments              80317 non-null object
# date_posted           80332 non-null object
# latitude              80332 non-null object
# longitude             80332 non-null float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
ufo_table.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration_seconds duration_hours_min  \
# 0             2700         45 minutes
# 1             7200            1-2 hrs
# 2               20         20 seconds
# 3               20           1/2 hour
# 4              900         15 minutes
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# ...

# %%
ufo_table.describe()
# Out:
#           longitude
# count  80332.000000
# mean     -86.772885
# std       39.697205
# min     -176.658056
# 25%     -112.073333
# 50%      -87.903611
# 75%      -78.755000
# max      178.441900

# %% [markdown]
# ## Datetime

# %%
# We will change the type of the columns to be able to do operations
ufo_table.astype({"datetime":"datetime64[ns]"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-2a086c73be16> in <module>
#       1 # We will...
# ----> 2 ufo_table.astype({"datetime":"datetime64[ns]"})
#
# ...

# %%
ufo_table["hour_error"] = ufo_table["datetime"].apply(lambda x: "24:" in x)

# %%
ufo_table[ufo_table["hour_error"]==True]
# Out:
#                datetime                                city state country  \
# 388    10/11/2006 24:00                                rome    ny      us
# 693     10/1/2001 24:00    chulucanas-piura la vieja (peru)   NaN     NaN
# 962     10/1/2012 24:00                                novi    mi      us
# 1067   10/12/2003 24:00                salatiga (indonesia)   NaN     NaN
# 1221   10/12/2013 24:00                          cincinnati    oh      us
# 1222   10/12/2013 24:00             orangevale (sacramento)    ca      us
# 1317   10/13/2004 24:00                          white hall    ar      us
# 1359   10/13/2007 24:00                              hudson    wi      us
# 1445   10/13/2012 24:00                            kingston    pa      us
# 1663   10/14/2011 24:00                   cibecue (west of)    az      us
# 1709   10/15/1952 24:00    edmonton (southwest of) (canada)    ab      ca
# 1754   10/15/1971 24:00            lago vista (near austin)    tx      us
# ...

# %%
ufo_table["datetime_corrected"] = ufo_table["datetime"].apply(lambda x: x.replace("24:", "00:"))

# %%
ufo_table[ufo_table["hour_error"]==True][["datetime", "datetime_corrected"]]
# Out:
#                datetime datetime_corrected
# 388    10/11/2006 24:00   10/11/2006 00:00
# 693     10/1/2001 24:00    10/1/2001 00:00
# 962     10/1/2012 24:00    10/1/2012 00:00
# 1067   10/12/2003 24:00   10/12/2003 00:00
# 1221   10/12/2013 24:00   10/12/2013 00:00
# 1222   10/12/2013 24:00   10/12/2013 00:00
# 1317   10/13/2004 24:00   10/13/2004 00:00
# 1359   10/13/2007 24:00   10/13/2007 00:00
# 1445   10/13/2012 24:00   10/13/2012 00:00
# 1663   10/14/2011 24:00   10/14/2011 00:00
# 1709   10/15/1952 24:00   10/15/1952 00:00
# 1754   10/15/1971 24:00   10/15/1971 00:00
# 1797   10/15/1978 24:00   10/15/1978 00:00
# 1809   10/15/1980 24:00   10/15/1980 00:00
# 1824   10/15/1983 24:00   10/15/1983 00:00
# 1949   10/15/1997 24:00   10/15/1997 00:00
# 1997   10/15/1999 24:00   10/15/1999 00:00
# 1998   10/15/1999 24:00   10/15/1999 00:00
# 2065   10/15/2002 24:00   10/15/2002 00:00
# 2146   10/15/2005 24:00   10/15/2005 00:00
# 2193   10/15/2008 24:00   10/15/2008 00:00
# ...

# %%
ufo_table["datetime"] = ufo_table["datetime"].apply(lambda x: x.replace("24:", "00:"))

# %%
ufo_table = ufo_table.astype({"datetime":"datetime64[ns]"})

# %%
ufo_table = ufo_table.drop(["hour_error", "datetime_corrected"], axis=1)

# %%
ufo_table.head()
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#   duration_seconds duration_hours_min  \
# 0             2700         45 minutes
# 1             7200            1-2 hrs
# 2               20         20 seconds
# 3               20           1/2 hour
# 4              900         15 minutes
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# ...

# %% [markdown]
# ## Latitude

# %%
ufo_table.astype({"latitude":float})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-d9d4f4e1e537> in <module>
# ----> 1 ufo_table.astype({"latitude":float})
#
# ~/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5676             for col_name, col in self.iteritems():
#    5677                 if col_name in dtype:
# -> 5678                     results.append(col.astype(dtype[col_name], copy=copy))
#    5679                 else:
#    5680                     results.append(results.append(col.copy() if copy else col))
#
# ~/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
ufo_table[ufo_table["latitude"] == "33q.200088"]
# Out:
#                  datetime                          city state country  \
# 43782 1974-05-22 05:30:00  mescalero indian reservation    nm     NaN
#
#            shape duration_seconds duration_hours_min  \
# 43782  rectangle              180          two hours
#
#                                                 comments date_posted  \
# 43782  Huge rectangular object emmitting intense whit...   4/18/2012
#
#          latitude   longitude
# 43782  33q.200088 -105.624152

# %%
ufo_table.shape
# Out:
# (80332, 11)

# %%
ufo_table = ufo_table.drop(43782)

# %%
ufo_table.shape
# Out:
# (80331, 11)

# %%
ufo_table = ufo_table.astype({"latitude":float})

# %%
ufo_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80331 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime              80331 non-null datetime64[ns]
# city                  80331 non-null object
# state                 74534 non-null object
# country               70662 non-null object
# shape                 78399 non-null object
# duration_seconds      80331 non-null object
# duration_hours_min    80331 non-null object
# comments              80316 non-null object
# date_posted           80331 non-null object
# latitude              80331 non-null float64
# longitude             80331 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 7.4+ MB

# %% [markdown]
# ## Duration_seconds

# %%
ufo_table.astype({"duration_seconds":float})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-593ff4643f5c> in <module>
# ----> 1 ufo_table.astype({"duration_seconds":float})
#
# ~/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5676             for col_name, col in self.iteritems():
#    5677                 if col_name in dtype:
# -> 5678                     results.append(col.astype(dtype[col_name], copy=copy))
#    5679                 else:
#    5680                     results.append(results.append(col.copy() if copy else col))
#
# ~/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
ufo_table[ufo_table["duration_seconds"] == "2`"]
# Out:
#                  datetime   city state country shape duration_seconds  \
# 27822 2000-02-02 19:33:00  bouse    az      us   NaN               2`
#
#        duration_hours_min                                           comments  \
# 27822  each a few seconds  Driving through Plomosa Pass towards Bouse Loo...
#
#       date_posted  latitude  longitude
# 27822   2/16/2000   33.9325   -114.005

# %%
ufo_table = ufo_table.drop(27822)

# %%
ufo_table.iloc[27822]
# Out:
# datetime                                            2000-02-02 19:49:00
# city                                                            seattle
# state                                                                wa
# country                                                              us
# shape                                                             other
# duration_seconds                                                    120
# duration_hours_min                                         aprox. 2 min
# comments              Watched two flying objects headed NW&#44 very ...
# date_posted                                                   2/16/2000
# latitude                                                        47.6064
# longitude                                                      -122.331
# Name: 27823, dtype: object

# %%
ufo_table.shape
# Out:
# (80330, 11)

# %%
ufo_table.astype({"duration_seconds":float})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-593ff4643f5c> in <module>
# ----> 1 ufo_table.astype({"duration_seconds":float})
#
# ~/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5676             for col_name, col in self.iteritems():
#    5677                 if col_name in dtype:
# -> 5678                     results.append(col.astype(dtype[col_name], copy=copy))
#    5679                 else:
#    5680                     results.append(results.append(col.copy() if copy else col))
#
# ~/anaconda3/envs/py3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
ufo_table["seconds_error"] = ufo_table["duration_seconds"].apply(lambda x: "`" in x)

# %%
ufo_table[ufo_table["seconds_error"]==True][["duration_seconds", "seconds_error"]]
# Out:
#       duration_seconds  seconds_error
# 35692               8`           True
# 58591             0.5`           True

# %%
ufo_table[ufo_table["seconds_error"]==True]
# Out:
#                  datetime               city state country   shape  \
# 35692 2005-04-10 22:52:00         santa cruz    ca      us     NaN
# 58591 2006-07-21 13:00:00  ibague (colombia)   NaN     NaN  circle
#
#       duration_seconds duration_hours_min  \
# 35692               8`      eight seconds
# 58591             0.5`        1/2 segundo
#
#                                                 comments date_posted  \
# 35692  2 red lights moving together and apart with a ...   4/16/2005
# 58591  Viajaba a 27.000 pies en un avion comercial ve...  10/30/2006
#
#         latitude   longitude  seconds_error
# 35692  36.974167 -122.029722           True
# 58591   4.440663  -75.244141           True

# %%
ufo_table = ufo_table.drop([35692, 58591])

# %%
ufo_table.shape
# Out:
# (80328, 12)

# %%
ufo_table = ufo_table.astype({"duration_seconds":float})

# %%
ufo_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80328 entries, 0 to 80331
# Data columns (total 12 columns):
# datetime              80328 non-null datetime64[ns]
# city                  80328 non-null object
# state                 74532 non-null object
# country               70660 non-null object
# shape                 78398 non-null object
# duration_seconds      80328 non-null float64
# duration_hours_min    80328 non-null object
# comments              80313 non-null object
# date_posted           80328 non-null object
# latitude              80328 non-null float64
# longitude             80328 non-null float64
# seconds_error         80328 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(3), object(7)
# memory usage: 7.4+ MB

# %%
ufo_table = ufo_table.drop("seconds_error", axis=1)

# %% [markdown]
# ## Date posted

# %%
ufo_table = ufo_table.astype({"date_posted": "datetime64[ns]"})

# %%
ufo_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80328 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime              80328 non-null datetime64[ns]
# city                  80328 non-null object
# state                 74532 non-null object
# country               70660 non-null object
# shape                 78398 non-null object
# duration_seconds      80328 non-null float64
# duration_hours_min    80328 non-null object
# comments              80313 non-null object
# date_posted           80328 non-null datetime64[ns]
# latitude              80328 non-null float64
# longitude             80328 non-null float64
# dtypes: datetime64[ns](2), float64(3), object(6)
# memory usage: 7.4+ MB

# %%
ufo_table.head()
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration_seconds duration_hours_min  \
# 0            2700.0         45 minutes
# 1            7200.0            1-2 hrs
# 2              20.0         20 seconds
# 3              20.0           1/2 hour
# 4             900.0         15 minutes
#
#                                             comments date_posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# ...

# %%
ufo_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80328 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime              80328 non-null datetime64[ns]
# city                  80328 non-null object
# state                 74532 non-null object
# country               70660 non-null object
# shape                 78398 non-null object
# duration_seconds      80328 non-null float64
# duration_hours_min    80328 non-null object
# comments              80313 non-null object
# date_posted           80328 non-null datetime64[ns]
# latitude              80328 non-null float64
# longitude             80328 non-null float64
# dtypes: datetime64[ns](2), float64(3), object(6)
# memory usage: 7.4+ MB

# %%
# Not the right way but the right method
ufo_table = ufo_table.fillna("")

# %%
ufo_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80328 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime              80328 non-null datetime64[ns]
# city                  80328 non-null object
# state                 80328 non-null object
# country               80328 non-null object
# shape                 80328 non-null object
# duration_seconds      80328 non-null float64
# duration_hours_min    80328 non-null object
# comments              80328 non-null object
# date_posted           80328 non-null datetime64[ns]
# latitude              80328 non-null float64
# longitude             80328 non-null float64
# dtypes: datetime64[ns](2), float64(3), object(6)
# memory usage: 7.4+ MB

# %% [markdown]
# ## More stuff

# %%
ufo_table[["duration_seconds"]].describe()
# Out:
#        duration_seconds
# count      8.032800e+04
# mean       9.017336e+03
# std        6.202322e+05
# min        1.000000e-03
# 25%        3.000000e+01
# 50%        1.800000e+02
# 75%        6.000000e+02
# max        9.783600e+07

# %%
lables = ["tipsy","drunk", "intoxicated"]

# %%
pd.cut(ufo_table["duration_seconds"], 3, labels=lables)
# Out:
# 0        tipsy
# 1        tipsy
# 2        tipsy
# 3        tipsy
# 4        tipsy
# 5        tipsy
# 6        tipsy
# 7        tipsy
# 8        tipsy
# 9        tipsy
# 10       tipsy
# 11       tipsy
# 12       tipsy
# 13       tipsy
# 14       tipsy
# 15       tipsy
# 16       tipsy
# 17       tipsy
# 18       tipsy
# 19       tipsy
# 20       tipsy
# 21       tipsy
# 22       tipsy
# 23       tipsy
# 24       tipsy
# 25       tipsy
# 26       tipsy
# 27       tipsy
# 28       tipsy
# 29       tipsy
#          ...
# 80302    tipsy
# 80303    tipsy
# 80304    tipsy
# 80305    tipsy
# 80306    tipsy
# 80307    tipsy
# 80308    tipsy
# 80309    tipsy
# 80310    tipsy
# 80311    tipsy
# 80312    tipsy
# 80313    tipsy
# 80314    tipsy
# 80315    tipsy
# 80316    tipsy
# 80317    tipsy
# 80318    tipsy
# 80319    tipsy
# 80320    tipsy
# 80321    tipsy
# 80322    tipsy
# 80323    tipsy
# 80324    tipsy
# 80325    tipsy
# 80326    tipsy
# 80327    tipsy
# 80328    tipsy
# ...

# %%
ufo_table["duration_seconds_label"] = pd.cut(ufo_table["duration_seconds"], 3, labels=lables)

# %%
ufo_table
# Out:
#                  datetime                                   city state  \
# 0     1949-10-10 20:30:00                             san marcos    tx
# 1     1949-10-10 21:00:00                           lackland afb    tx
# 2     1955-10-10 17:00:00                   chester (uk/england)
# 3     1956-10-10 21:00:00                                   edna    tx
# 4     1960-10-10 20:00:00                                kaneohe    hi
# 5     1961-10-10 19:00:00                                bristol    tn
# 6     1965-10-10 21:00:00                     penarth (uk/wales)
# 7     1965-10-10 23:45:00                                norwalk    ct
# 8     1966-10-10 20:00:00                              pell city    al
# 9     1966-10-10 21:00:00                               live oak    fl
# 10    1968-10-10 13:00:00                              hawthorne    ca
# 11    1968-10-10 19:00:00                                brevard    nc
# ...

# %%
ufo_table["duration_seconds_label"].value_counts()
# Out:
# tipsy          80322
# intoxicated        3
# drunk              3
# Name: duration_seconds_label, dtype: int64

# %%
pd.cut(ufo_table["duration_seconds"], 3, retbins=True)
# Out:
# (0        (-97835.999, 32612000.001]
#  1        (-97835.999, 32612000.001]
#  2        (-97835.999, 32612000.001]
#  3        (-97835.999, 32612000.001]
#  4        (-97835.999, 32612000.001]
#  5        (-97835.999, 32612000.001]
#  6        (-97835.999, 32612000.001]
#  7        (-97835.999, 32612000.001]
#  8        (-97835.999, 32612000.001]
#  9        (-97835.999, 32612000.001]
#  10       (-97835.999, 32612000.001]
#  11       (-97835.999, 32612000.001]
#  12       (-97835.999, 32612000.001]
#  13       (-97835.999, 32612000.001]
#  14       (-97835.999, 32612000.001]
#  15       (-97835.999, 32612000.001]
#  16       (-97835.999, 32612000.001]
#  17       (-97835.999, 32612000.001]
#  18       (-97835.999, 32612000.001]
#  19       (-97835.999, 32612000.001]
#  20       (-97835.999, 32612000.001]
#  21       (-97835.999, 32612000.001]
#  22       (-97835.999, 32612000.001]
#  23       (-97835.999, 32612000.001]
#  24       (-97835.999, 32612000.001]
# ...
