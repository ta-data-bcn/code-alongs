# %% [markdown]
# Data from https://www.kaggle.com/c/competitive-data-science-predict-future-sales/data

# %%
import pandas as pd

# %%
test = pd.read_csv('sales_train.csv')

# %%
test.drop('date_block_num', axis = 1, inplace = True)

# %%
test.groupby('date').count()
# Out:
#             shop_id  item_id  item_price  item_cnt_day
# date
# 01.01.2013     1669     1669        1669          1669
# 01.01.2014     1852     1852        1852          1852
# 01.01.2015     1673     1673        1673          1673
# 01.02.2013     3356     3356        3356          3356
# 01.02.2014     4691     4691        4691          4691
# 01.02.2015     2925     2925        2925          2925
# 01.03.2013     3491     3491        3491          3491
# 01.03.2014     4554     4554        4554          4554
# 01.03.2015     2825     2825        2825          2825
# 01.04.2013     2338     2338        2338          2338
# 01.04.2014     1851     1851        1851          1851
# 01.04.2015     1515     1515        1515          1515
# 01.05.2013     4255     4255        4255          4255
# 01.05.2014     3133     3133        3133          3133
# 01.05.2015     2359     2359        2359          2359
# 01.06.2013     4581     4581        4581          4581
# ...

# %%
dates = list(set(test['date']))

# %%
dates[0]
# Out:
# '09.05.2013'

# %%
test[test['date'] == dates[0]]
# Out:
#               date  shop_id  item_id  item_price  item_cnt_day
# 439775  09.05.2013       27    20553       529.0           1.0
# 439776  09.05.2013       27    20417      1299.0           1.0
# 439831  09.05.2013       27    20231        99.0           1.0
# 439835  09.05.2013       27    20328       349.0           1.0
# 439853  09.05.2013       27    21440       399.0           1.0
# 439905  09.05.2013       27    21371      1199.0           1.0
# 439933  09.05.2013       27    21376       399.0           1.0
# 439981  09.05.2013       27    18617       199.0           1.0
# 439984  09.05.2013       27    18460       299.0           1.0
# 439998  09.05.2013       27    18312       299.0           1.0
# 440023  09.05.2013       27    18486       299.0           1.0
# 440035  09.05.2013       27    19602        99.0           1.0
# 440041  09.05.2013       27    19597        99.0           2.0
# 440098  09.05.2013       27    19536       399.0           1.0
# ...

# %% [markdown]
# Saving only april 2015 (enough)

# %%
for date in dates:
    if '04.2015' in date:
        test[test['date'] == date].to_csv(f'data/sales_{date}.csv')
        print(date)
# Out:
# 13.04.2015
# 30.04.2015
# 11.04.2015
# 16.04.2015
# 03.04.2015
# 05.04.2015
# 24.04.2015
# 25.04.2015
# 23.04.2015
# 27.04.2015
# 29.04.2015
# 22.04.2015
# 15.04.2015
# 19.04.2015
# 10.04.2015
# 09.04.2015
# 12.04.2015
# 08.04.2015
# 20.04.2015
# 21.04.2015
# 06.04.2015
# 04.04.2015
# 07.04.2015
# 28.04.2015
# 26.04.2015
# 17.04.2015
# 14.04.2015
# 02.04.2015
# 18.04.2015
# 01.04.2015

# %%
data = pd.read_csv('data/sales_01.04.2015.csv')

# %%
data = data.drop('Unnamed: 0', axis = 1)

# %%
data.head(1)
# Out:
#          date  shop_id  item_id  item_price  item_cnt_day
# 0  01.04.2015       29     1469      1199.0           1.0

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
by_shop = data.groupby('shop_id').sum().drop(['item_id'], axis = 1)
by_shop = by_shop.rename(columns = {'item_price': 'shop_earnings', 'item_cnt_day': 'total_items_sold'})

# %%
import datetime as dt

# %%
by_shop['date'] = dt.datetime.today().strftime("%m/%d/%Y")

# %%
by_item = data.groupby('item_id').sum().drop(['shop_id'], axis = 1)
by_item = by_item.rename(columns = {'item_price': 'item_earnings', 'item_cnt_day': 'total_items_sold'})

# %%
by_item['date'] = dt.datetime.today().strftime("%m/%d/%Y")

# %%
by_item
# Out:
#          item_earnings  total_items_sold        date
# item_id
# 30              169.00               1.0  03/07/2019
# 31              363.00               1.0  03/07/2019
# 32              149.00               1.0  03/07/2019
# 42              299.00               1.0  03/07/2019
# 59              249.00               1.0  03/07/2019
# 74              499.00               1.0  03/07/2019
# 109             249.00               1.0  03/07/2019
# 259             249.00               1.0  03/07/2019
# 464             299.00               1.0  03/07/2019
# 482            6600.00               4.0  03/07/2019
# 486            1500.00               7.0  03/07/2019
# 492             600.00               1.0  03/07/2019
# 493             250.00               1.0  03/07/2019
# 494             380.00               1.0  03/07/2019
# 686            1500.00               1.0  03/07/2019
# 687             600.00               1.0  03/07/2019
# 787             420.00               1.0  03/07/2019
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://ironhacker_read:ir0nhack3r@35.239.232.23/retail_sales_playground')

# %%
data.to_sql('raw_sales', engine, if_exists= 'append', index = False)

# %%
by_item.to_sql('sales_by_item_2', engine, if_exists='append')

# %%
by_item
# Out:
#          item_earnings  total_items_sold        date
# item_id
# 30              169.00               1.0  03/07/2019
# 31              363.00               1.0  03/07/2019
# 32              149.00               1.0  03/07/2019
# 42              299.00               1.0  03/07/2019
# 59              249.00               1.0  03/07/2019
# 74              499.00               1.0  03/07/2019
# 109             249.00               1.0  03/07/2019
# 259             249.00               1.0  03/07/2019
# 464             299.00               1.0  03/07/2019
# 482            6600.00               4.0  03/07/2019
# 486            1500.00               7.0  03/07/2019
# 492             600.00               1.0  03/07/2019
# 493             250.00               1.0  03/07/2019
# 494             380.00               1.0  03/07/2019
# 686            1500.00               1.0  03/07/2019
# 687             600.00               1.0  03/07/2019
# 787             420.00               1.0  03/07/2019
# ...
